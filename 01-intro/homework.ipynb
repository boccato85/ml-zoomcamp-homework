# %%
import numpy as np
import pandas as pd

# %%
    pd.__version__
# Out:
# '2.3.3'

# %%
df = pd.read_csv("https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv")

# %%
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# 3            16.912736
# 4            12.488369

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# 1             17.8        2007     USA  Gasoline  Front-wheel drive
# 2             15.1        2018  Europe  Gasoline  Front-wheel drive
# 3             20.2        2009     USA    Diesel    All-wheel drive
# 4             14.4        2009  Europe  Gasoline    All-wheel drive
# ...            ...         ...     ...       ...                ...
# 9699          17.3        2013  Europe    Diesel  Front-wheel drive
# 9700          15.0        2004     USA  Gasoline    All-wheel drive
# 9701          15.1        2008     USA    Diesel    All-wheel drive
# 9702          19.4        2011     USA    Diesel  Front-wheel drive
# 9703          14.7        2005    Asia    Diesel    All-wheel drive
#
#       num_doors  fuel_efficiency_mpg
# 0           0.0            13.231729
# 1           0.0            13.688217
# 2           0.0            14.246341
# 3           2.0            16.912736
# 4           2.0            12.488369
# ...         ...                  ...
# 9699        NaN            15.101802
# 9700        0.0            17.962326
# 9701       -1.0            17.186587
# 9702        1.0            15.331551
# 9703       -1.0            14.884467
#
# [9704 rows x 11 columns]

# %%
df.fuel_type
# Out:
# 0       Gasoline
# 1       Gasoline
# 2       Gasoline
# 3         Diesel
# 4       Gasoline
#           ...
# 9699      Diesel
# 9700    Gasoline
# 9701      Diesel
# 9702      Diesel
# 9703      Diesel
# Name: fuel_type, Length: 9704, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9704, step=1)

# %%
df.fuel_type.nunique()
# Out:
# 2

# %%
df.nunique()
# Out:
# engine_displacement      36
# num_cylinders            14
# horsepower              192
# vehicle_weight         9704
# acceleration            162
# model_year               24
# origin                    3
# fuel_type                 2
# drivetrain                2
# num_doors                 9
# fuel_efficiency_mpg    9704
# dtype: int64

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df.fuel_efficiency_mpg.max()
# Out:
# np.float64(25.96722204888372)

# %%
df.columns
# Out:
# Index(['engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'model_year', 'origin', 'fuel_type', 'drivetrain',
#        'num_doors', 'fuel_efficiency_mpg'],
#       dtype='object')

# %%
df.sort_values(by='fuel_efficiency_mpg', ascending=False)
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 5014                  210            3.0       206.0      952.681761
# 5815                  180            2.0       188.0     1066.328301
# 9387                  330            3.0       136.0     1223.298226
# 560                   240            5.0       151.0     1314.839625
# 8300                  140            2.0       113.0     1336.444231
# ...                   ...            ...         ...             ...
# 6049                  130            1.0       165.0     4739.077089
# 7938                  220            4.0       144.0     4527.955273
# 4935                  160            1.0       166.0     4604.494580
# 5037                  220            0.0       132.0     4643.568672
# 4887                   90            3.0       174.0     4726.977269
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 5014          18.5        2015  Europe  Gasoline  Front-wheel drive
# 5815           NaN        2013     USA  Gasoline  Front-wheel drive
# 9387           NaN        2001    Asia  Gasoline  Front-wheel drive
# 560           15.0        2012     USA  Gasoline  Front-wheel drive
# 8300          16.2        2015  Europe    Diesel  Front-wheel drive
# ...            ...         ...     ...       ...                ...
# 6049           NaN        2008     USA    Diesel    All-wheel drive
# 7938          21.9        2023  Europe  Gasoline    All-wheel drive
# 4935          16.4        2007     USA    Diesel    All-wheel drive
# 5037          15.2        2020  Europe    Diesel    All-wheel drive
# 4887          16.5        2020  Europe    Diesel  Front-wheel drive
#
#       num_doors  fuel_efficiency_mpg
# 5014       -1.0            25.967222
# 5815        2.0            24.971452
# 9387        1.0            23.759123
# 560         0.0            23.556075
# 8300        1.0            23.369176
# ...         ...                  ...
# 6049       -1.0             6.805975
# 7938       -1.0             6.762991
# 4935        0.0             6.695483
# 5037        1.0             6.676475
# 4887        1.0             6.200971
#
# [9704 rows x 11 columns]

# %%
df.vehicle_weight.sum()
# Out:
# np.float64(29124430.759692907)
